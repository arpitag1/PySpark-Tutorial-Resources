# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("spark://spark-master:7077") \
    .appName("ReadData2") \
    .getOrCreate()

# %%
df_csv = spark.read.csv("/opt/spark-data/Morning_Routine_Productivity.csv", header=True, inferSchema=True)

# %%
df_csv.show()

# %%
df_json = spark.read.json("/opt/spark-data/zipcodes.json")

# %%
df_json.show()

# %%
df_parquet = spark.read.parquet('/opt/spark-data/0000.parquet')

# %%
df_parquet.show()
