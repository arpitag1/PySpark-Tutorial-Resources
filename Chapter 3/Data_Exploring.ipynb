# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("spark://spark-master:7077") \
    .appName("SalesDataAnalysis") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/06 14:07:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv("/opt/spark-data/Sales/orders.csv", header=True, inferSchema=True)

# %%
df.show()
# Out:
# +--------+-----------+----------+----------+--------+----------+---------+
# |order_id|customer_id|product_id|order_date|quantity|unit_price|   status|
# +--------+-----------+----------+----------+--------+----------+---------+
# |    1001|       C001|      P101|2024-01-05|       2|     29.99|Completed|
# |    1002|       C002|      P102|2024-01-07|       1|    149.99|Completed|
# |    1003|       C003|      P103|2024-01-10|       5|      9.99|Completed|
# |    1004|       C001|      P104|2024-01-12|       3|     49.99|Cancelled|
# |    1005|       C004|      P101|2024-01-15|       1|     29.99|Completed|
# |    1006|       C005|      P105|2024-01-18|       2|     89.99|  Pending|
# |    1007|       C002|      P103|2024-01-20|       4|      9.99|Completed|
# |    1008|       C006|      P102|2024-01-22|       1|    149.99|Completed|
# |    1009|       C003|      P104|2024-01-25|       2|     49.99|  Pending|
# |    1010|       C007|      P105|2024-01-28|       3|     89.99|Completed|
# |    1011|       C004|      P101|2024-02-01|       1|     29.99|Completed|
# |    1012|       C008|      P103|2024-02-03|       6|      9.99|Cancelled|
# |    1013|       C005|      P102|2024-02-06|       2|    149.99|Completed|
# |    1014|       C006|      P104|2024-02-08|       1|     49.99|Completed|
# |    1015|       C009|      P105|2024-02-10|       4|     89.99|Completed|
# +--------+-----------+----------+----------+--------+----------+---------+

# %%
df.show(5)
# Out:
# +--------+-----------+----------+----------+--------+----------+---------+
# |order_id|customer_id|product_id|order_date|quantity|unit_price|   status|
# +--------+-----------+----------+----------+--------+----------+---------+
# |    1001|       C001|      P101|2024-01-05|       2|     29.99|Completed|
# |    1002|       C002|      P102|2024-01-07|       1|    149.99|Completed|
# |    1003|       C003|      P103|2024-01-10|       5|      9.99|Completed|
# |    1004|       C001|      P104|2024-01-12|       3|     49.99|Cancelled|
# |    1005|       C004|      P101|2024-01-15|       1|     29.99|Completed|
# +--------+-----------+----------+----------+--------+----------+---------+
# only showing top 5 rows

# %%
df.show(5, truncate=False)
# Out:
# +--------+-----------+----------+----------+--------+----------+---------+
# |order_id|customer_id|product_id|order_date|quantity|unit_price|status   |
# +--------+-----------+----------+----------+--------+----------+---------+
# |1001    |C001       |P101      |2024-01-05|2       |29.99     |Completed|
# |1002    |C002       |P102      |2024-01-07|1       |149.99    |Completed|
# |1003    |C003       |P103      |2024-01-10|5       |9.99      |Completed|
# |1004    |C001       |P104      |2024-01-12|3       |49.99     |Cancelled|
# |1005    |C004       |P101      |2024-01-15|1       |29.99     |Completed|
# +--------+-----------+----------+----------+--------+----------+---------+
# only showing top 5 rows

# %%
df.show(5, truncate=6)
# Out:
# +--------+-----------+----------+----------+--------+----------+------+
# |order_id|customer_id|product_id|order_date|quantity|unit_price|status|
# +--------+-----------+----------+----------+--------+----------+------+
# |    1001|       C001|      P101|    202...|       2|     29.99|Com...|
# |    1002|       C002|      P102|    202...|       1|    149.99|Com...|
# |    1003|       C003|      P103|    202...|       5|      9.99|Com...|
# |    1004|       C001|      P104|    202...|       3|     49.99|Can...|
# |    1005|       C004|      P101|    202...|       1|     29.99|Com...|
# +--------+-----------+----------+----------+--------+----------+------+
# only showing top 5 rows

# %%
df.show(5, vertical=True)
# Out:
# -RECORD 0-----------------
#  order_id    | 1001
#  customer_id | C001
#  product_id  | P101
#  order_date  | 2024-01-05
#  quantity    | 2
#  unit_price  | 29.99
#  status      | Completed
# -RECORD 1-----------------
#  order_id    | 1002
#  customer_id | C002
#  product_id  | P102
#  order_date  | 2024-01-07
#  quantity    | 1
#  unit_price  | 149.99
#  status      | Completed
# -RECORD 2-----------------
#  order_id    | 1003
#  customer_id | C003
#  product_id  | P103
#  order_date  | 2024-01-10
#  quantity    | 5
#  unit_price  | 9.99
#  status      | Completed
# -RECORD 3-----------------
#  order_id    | 1004
#  customer_id | C001
#  product_id  | P104
#  order_date  | 2024-01-12
#  quantity    | 3
#  unit_price  | 49.99
#  status      | Cancelled
# -RECORD 4-----------------
#  order_id    | 1005
#  customer_id | C004
#  product_id  | P101
#  order_date  | 2024-01-15
#  quantity    | 1
#  unit_price  | 29.99
#  status      | Completed
# only showing top 5 rows

# %%
df.describe().show()
# Out:
# 26/05/06 14:28:19 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 7:>                                                          (0 + 1) / 1]
# +-------+----------------+-----------+----------+------------------+------------------+---------+
# |summary|        order_id|customer_id|product_id|          quantity|        unit_price|   status|
# +-------+----------------+-----------+----------+------------------+------------------+---------+
# |  count|              15|         15|        15|                15|                15|       15|
# |   mean|          1008.0|       NULL|      NULL| 2.533333333333333| 65.99000000000001|     NULL|
# | stddev|4.47213595499958|       NULL|      NULL|1.5976172734359606|51.380930314660525|     NULL|
# |    min|            1001|       C001|      P101|                 1|              9.99|Cancelled|
# |    max|            1015|       C009|      P105|                 6|            149.99|  Pending|
# +-------+----------------+-----------+----------+------------------+------------------+---------+

# %%
df.describe(['unit_price']).show()
# Out:
# +-------+------------------+
# |summary|        unit_price|
# +-------+------------------+
# |  count|                15|
# |   mean| 65.99000000000001|
# | stddev|51.380930314660525|
# |    min|              9.99|
# |    max|            149.99|
# +-------+------------------+

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- status: string (nullable = true)

# %%
df.printSchema(2)
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- status: string (nullable = true)

# %%
df.columns
# Out:
# ['order_id',
#  'customer_id',
#  'product_id',
#  'order_date',
#  'quantity',
#  'unit_price',
#  'status']
